# %% [markdown]
# # Universal Setup (Run this first!)

# %%
"""This notebook works in both:
 - Google Colab
 - Local Jupyter (your own machine)
 
 Just run this cell and everything will work!"""
"""Setup for Colab """
from google.colab import drive
drive.mount('/content/drive')

# Import the universal setup
import sys
import os
os.chdir('/content/drive/MyDrive/ddi_prediction')

# !pip install -e . -q
print("Setup complete!")
# Out:
# Setup complete!
# ERROR: file:///C:/Users/linar/Documents/ddi-prediction/notebooks does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.
