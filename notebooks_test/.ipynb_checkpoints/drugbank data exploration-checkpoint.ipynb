# %%
import sys
sys.path.append("../") # Go up one level to project root 
from src_test import drugbank_parse
import pandas as pd

# %%
# Set your XML file path
xml_path = "../data/raw/drugbank_all_full_database_V5.1.14.xml.zip"

# %%
# Create parser instance
parser = drugbank_parse.DrugBankParser(xml_path)

# %%
drugs_dict = parser.parse_drugs_from_xml(
    limit = 10, 
    required_fields = ['name', 'smiles', 'groups']

)
print(f"Successfully parsed {len(drugs_dict)} drugs")
# Out:
# Found XML file: full database.xml
